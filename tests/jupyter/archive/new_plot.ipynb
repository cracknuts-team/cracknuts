# %%
from cracknuts.trace import ZarrTraceDataset

zd = ZarrTraceDataset.load(r'D:\work\01.testing\02.fly(gpio02)\cracknuts\tests\jupyter\dataset\20251029153409_1200_power_8m_30.zarr')

p = zd.plot()
p.show_trace(0, slice(2,20))
f = p.plot_line()
f
# Out:
# FigureWidgetResampler({
#     'data': [{'line': {'width': 1},
#               'mode': 'lines',
#               'name': '<b style="color:sandybrown">[R]</b> T2 <i style="color:#fc9944">~80k</i>',
#               'showlegend': True,
#               'type': 'scattergl',
#               'uid': 'edd5861e-d4a3-4a0c-b358-d117d99d18ac',
#               'x': {'bdata': ('AAAAAOAJAAANawEAUiEDALbZAwBvSA' ... 'SXx78EPy/BBBqywgRDVcQE/7PEBA=='),
#                     'dtype': 'i4'},
#               'y': {'bdata': ('AgDSAdb/LQDX/yoA0f8rANT/LgDV/y' ... '0Az/8wANH/MwDM/zIA0P80ADAA9v8='),
#                     'dtype': 'i2'}},
#              {'line': {'width': 1},
#               'mode': 'lines',
#               'name': '<b style="color:sandybrown">[R]</b> T3 <i style="color:#fc9944">~80k</i>',
#               'showlegend': True,
#               'type': 'scattergl',
#               'uid': 'acebbb52-1cec-46e0-bedd-437a34e635d4',
#               'x': {'bdata': ('AAAAANQJAADYWwEADXMCAMTxAwAv8A' ... 'THy78EqkPBBMHbwQQ4ecME/7PEBA=='),
#                     'dtype': 'i4'},
#               'y': {'bdata': ('DwC7AtT/KwDW/ysA1f8sANf/LQDV/y' ... 'P/MgDR/zIAzP88ANP/NgDT/zMACAA='),
#                     'dtype': 'i2'}},
#              {'line': {'width': 1},
#               'mode': 'lines',
#               'name': '<b style="color:sandybrown">[R]</b> T4 <i style="color:#fc9944">~80k</i>',
#               'showlegend': True,
#               'type': 'scattergl',
#               'uid': '607a1279-4b7e-461a-b73f-311c8dc7b3c2',
#               'x': {'bdata': ('AAAAAM8JAABZsAEAsfwCAJfAAwC3FA' ... 'Qigr8EE67ABNbVwgSRE8ME/7PEBA=='),
#                     'dtype': 'i4'},
#               'y': {'bdata': ('+P+uAdb/LQDW/ysA1/8sANX/LgDX/y' ... 'H/LgDS/zUA0f85ANL/NADS/zQAAwA='),
#                     'dtype': 'i2'}},
#              {'line': {'width': 1},
#               'mode': 'lines',
#               'name': '<b style="color:sandybrown">[R]</b> T5 <i style="color:#fc9944">~80k</i>',
#               'showlegend': True,
#               'type': 'scattergl',
#               'uid': '19c36a57-4eed-4253-8e5a-dad6c20f4472',
#               'x': {'bdata': ('AAAAANIJAACOhAEAudgCAFz/AwCbTg' ... 'QH+r8EyQXCBC8jwgQktsME/7PEBA=='),
#                     'dtype': 'i4'},
#               'y': {'bdata': ('EAAAA9X/KwDV/ywA1v8sANj/LQDY/y' ... 'IAzv8xANH/MgDN/zcANQDQ/zQABwA='),
#                     'dtype': 'i2'}},
#              {'line': {'width': 1},
#               'mode': 'lines',
#               'name': '<b style="color:sandybrown">[R]</b> T6 <i style="color:#fc9944">~80k</i>',
#               'showlegend': True,
#               'type': 'scattergl',
#               'uid': '7aa0244f-0efe-4953-8e9e-1341b2f57528',
#               'x': {'bdata': ('AAAAAAEKAAB+pAEAggoDAL4mBAAu8g' ... 'ThpL8E3LPABDRSwgQwMcQE/7PEBA=='),
#                     'dtype': 'i4'},
#               'y': {'bdata': ('//8XAdX/LgDT/ywA0/8sANb/KwDW/y' ... 'L/NQDQ/y4AMgDT/zAAz/8zAC8ABwA='),
#                     'dtype': 'i2'}},
#              {'line': {'width': 1},
#               'mode': 'lines',
#               'name': '<b style="color:sandybrown">[R]</b> T7 <i style="color:#fc9944">~80k</i>',
#               'showlegend': True,
#               'type': 'scattergl',
#               'uid': 'e3b1ae87-e117-4d96-b81a-bd83d08972ea',
#               'x': {'bdata': ('AAAAAO4JAABPfAEA76sCAEYCBACM/Q' ... 'Tahb8Ef5jABAkMwgQSVMQE/7PEBA=='),
#                     'dtype': 'i4'},
#               'y': {'bdata': ('/f+sAc//LADX/y4A1P8sANb/LgDW/y' ... 'MA0f8vANL/MQDN/zQA0v8yAC4A4P8='),
#                     'dtype': 'i2'}},
#              {'line': {'width': 1},
#               'mode': 'lines',
#               'name': '<b style="color:sandybrown">[R]</b> T8 <i style="color:#fc9944">~80k</i>',
#               'showlegend': True,
#               'type': 'scattergl',
#               'uid': '8c8f066d-7d42-4a75-9263-8c15eb93a503',
#               'x': {'bdata': ('AAAAAMgJAACnbgEAeowCACvuAwD+Sw' ... 'Szi78EzRHBBFJiwgQ9OcQE/7PEBA=='),
#                     'dtype': 'i4'},
#               'y': {'bdata': ('FAByAtb/LwDQ/y4A1/8vANX/KwDW/y' ... 'P/MADU/y8A0/8xAM7/LgDV/9H/CAA='),
#                     'dtype': 'i2'}},
#              {'line': {'width': 1},
#               'mode': 'lines',
#               'name': '<b style="color:sandybrown">[R]</b> T9 <i style="color:#fc9944">~80k</i>',
#               'showlegend': True,
#               'type': 'scattergl',
#               'uid': '9c1e4073-32fb-4165-90a7-9aba96deec58',
#               'x': {'bdata': ('AAAAAMkJAADlYgEAFrcCADTeAwCxJA' ... 'Sper8Ekv/ABI4twgSqG8QE/7PEBA=='),
#                     'dtype': 'i4'},
#               'y': {'bdata': ('5v9sAtb/KwDW/y8A0f8rANP/KwDX/y' ... 'D/MADR/zEA0/82ANP/LwDU/8//FgA='),
#                     'dtype': 'i2'}},
#              {'line': {'width': 1},
#               'mode': 'lines',
#               'name': '<b style="color:sandybrown">[R]</b> T10 <i style="color:#fc9944">~80k</i>',
#               'showlegend': True,
#               'type': 'scattergl',
#               'uid': 'a1844166-d7aa-4ce7-8632-4fdc71157a2b',
#               'x': {'bdata': ('AAAAAOwJAABEPQEALJICAGXbAwDH7A' ... 'THxb8EtRzBBMBqwgT8fMQE/7PEBA=='),
#                     'dtype': 'i4'},
#               'y': {'bdata': ('+v+SAtT/LADX/ywA1/8sANP/KgDV/y' ... 'L/LQDU/zQA0f8yAM//LADQ/87/GQA='),
#                     'dtype': 'i2'}},
#              {'line': {'width': 1},
#               'mode': 'lines',
#               'name': '<b style="color:sandybrown">[R]</b> T11 <i style="color:#fc9944">~80k</i>',
#               'showlegend': True,
#               'type': 'scattergl',
#               'uid': '5491f244-6cb7-4f75-b9f7-9f1510d00a29',
#               'x': {'bdata': ('AAAAAM0JAADOfgEAlL4CALHHAwCzAg' ... 'RKor8ESOTABNs/wgSYCcME/7PEBA=='),
#                     'dtype': 'i4'},
#               'y': {'bdata': ('9f/MA9b/KwDX/ysA1P8rANX/LADX/y' ... 'YA0f8wAM//MwAzANP/NgDQ/zIA+f8='),
#                     'dtype': 'i2'}},
#              {'line': {'width': 1},
#               'mode': 'lines',
#               'name': '<b style="color:sandybrown">[R]</b> T12 <i style="color:#fc9944">~80k</i>',
#               'showlegend': True,
#               'type': 'scattergl',
#               'uid': 'd8cdbb02-00d4-425e-b542-6c6765f3094f',
#               'x': {'bdata': ('AAAAANMJAAAgmAEAn+MCAE7FAwBSWg' ... 'Q7zb8EZgHBBKoBwgTl38ME/7PEBA=='),
#                     'dtype': 'i4'},
#               'y': {'bdata': ('+f9/A9f/KwDX/ysA2P8rANX/KwDW/y' ... 'MAzv8yAM//NgDO/zAA0/81ANX/8P8='),
#                     'dtype': 'i2'}},
#              {'line': {'width': 1},
#               'mode': 'lines',
#               'name': '<b style="color:sandybrown">[R]</b> T13 <i style="color:#fc9944">~80k</i>',
#               'showlegend': True,
#               'type': 'scattergl',
#               'uid': '03f0fbc4-8785-4577-ac4b-b74e2587bf82',
#               'x': {'bdata': ('AAAAAM0JAADXYwEAyfACAEjRAwA/OQ' ... 'S4vL8ELITBBLB9wgS2McME/7PEBA=='),
#                     'dtype': 'i4'},
#               'y': {'bdata': ('DQAJBNf/LwDY/ysA1f8qANj/LQDY/y' ... 'IA0P83ANH/LQDR/y8A0P8wANT/BAA='),
#                     'dtype': 'i2'}},
#              {'line': {'width': 1},
#               'mode': 'lines',
#               'name': '<b style="color:sandybrown">[R]</b> T14 <i style="color:#fc9944">~80k</i>',
#               'showlegend': True,
#               'type': 'scattergl',
#               'uid': '23f4d574-c09e-40c5-ae2e-cd68446f9323',
#               'x': {'bdata': ('AAAAAMIJAADZSgEAtYICAOYaBADO7A' ... 'TPKcAEFmzBBCItwgRpMcQE/7PEBA=='),
#                     'dtype': 'i4'},
#               'y': {'bdata': ('AQC9A9X/LwDV/ywA0v8rANf/KgDX/y' ... '7/MwDR/y4A0P8uANT/OgDS/9D/BAA='),
#                     'dtype': 'i2'}},
#              {'line': {'width': 1},
#               'mode': 'lines',
#               'name': '<b style="color:sandybrown">[R]</b> T15 <i style="color:#fc9944">~80k</i>',
#               'showlegend': True,
#               'type': 'scattergl',
#               'uid': '9eeca0b1-2515-4de3-a4ae-c3379818935b',
#               'x': {'bdata': ('AAAAANcJAABvfAEArYACAMDPAwAXNA' ... 'T9rb8EI3zBBCyMwgQlbMME/7PEBA=='),
#                     'dtype': 'i4'},
#               'y': {'bdata': ('9/8LBNT/LADT/ysA1P8uANb/KgDY/y' ... 'X/LwDQ/zYA0P8zANH/LwDV/y4AAAA='),
#                     'dtype': 'i2'}},
#              {'line': {'width': 1},
#               'mode': 'lines',
#               'name': '<b style="color:sandybrown">[R]</b> T16 <i style="color:#fc9944">~80k</i>',
#               'showlegend': True,
#               'type': 'scattergl',
#               'uid': '3fa2be0e-b3aa-48dc-84f1-4a8947cb3e62',
#               'x': {'bdata': ('AAAAAMwJAACUSwEAurQCALLLAwB+6Q' ... 'S1nL8EwL7ABL5cwgR6U8ME/7PEBA=='),
#                     'dtype': 'i4'},
#               'y': {'bdata': ('BABMBdf/MADY/ywA1v8qANf/NADR/y' ... '//MQDS/y0A0P/R/zUA0f8xANL/DwA='),
#                     'dtype': 'i2'}},
#              {'line': {'width': 1},
#               'mode': 'lines',
#               'name': '<b style="color:sandybrown">[R]</b> T17 <i style="color:#fc9944">~80k</i>',
#               'showlegend': True,
#               'type': 'scattergl',
#               'uid': '8b73f3e2-70d6-4dc5-a4e6-580b18dd39c2',
#               'x': {'bdata': ('AAAAALgJAAAOUwEAIt8CAJirAwA9MQ' ... 'QtEMAES5HBBE1DwgSUesME/7PEBA=='),
#                     'dtype': 'i4'},
#               'y': {'bdata': ('+P+tBdf/LQDX/y0A1v8rANj/LQDX/y' ... '8A0P8zANP/MADS/ywA0v8yANL/DwA='),
#                     'dtype': 'i2'}},
#              {'line': {'width': 1},
#               'mode': 'lines',
#               'name': '<b style="color:sandybrown">[R]</b> T18 <i style="color:#fc9944">~80k</i>',
#               'showlegend': True,
#               'type': 'scattergl',
#               'uid': 'c6108ae0-1622-44ca-950b-48be96e433ea',
#               'x': {'bdata': ('AAAAAKsJAAAAdwEAs/wCADK3AwDJXg' ... 'Sd078EySnBBOITwgTVHsME/7PEBA=='),
#                     'dtype': 'i4'},
#               'y': {'bdata': ('5/+6BNb/LADO/y0A1f8yANT/MQDW/y' ... '8A0f86AM//MwDP/zYA0/8vANH//P8='),
#                     'dtype': 'i2'}},
#              {'line': {'width': 1},
#               'mode': 'lines',
#               'name': '<b style="color:sandybrown">[R]</b> T19 <i style="color:#fc9944">~80k</i>',
#               'showlegend': True,
#               'type': 'scattergl',
#               'uid': 'aeb954a1-9c73-4a3f-93bf-ce64a43ec3f0',
#               'x': {'bdata': ('AAAAAKwJAAByagEAXpQCAEGyAwAufQ' ... 'QnxL8Eot3ABLFMwgSqNsQE/7PEBA=='),
#                     'dtype': 'i4'},
#               'y': {'bdata': ('/P/uA9T/LgDW/y0A1f8uANP/LgDT/y' ... 'T/MQDV/8//NADQ/zcA0f8sAC0ABQA='),
#                     'dtype': 'i2'}}],
#     'layout': {'height': 350,
#                'margin': {'b': 40, 'l': 0, 't': 40},
#                'paper_bgcolor': 'white',
#                'plot_bgcolor': 'white',
#                'template': '...',
#                'xaxis': {'gridcolor': '#dddddd',
#                          'gridwidth': 1,
#                          'linecolor': '#dddddd',
#                          'linewidth': 1,
#                          'mirror': True,
#                          'showline': True},
#                'yaxis': {'gridcolor': '#dddddd',
#                          'gridwidth': 1,
#                          'linecolor': '#dddddd',
#                          'linewidth': 1,
#                          'mirror': True,
#                          'showline': True}}
# })

# %%
p.zoom(x=(10000, 20000), y=(0, 200))

# %%
r = 9000000
start = 3000
f.layout.xaxis.range = [start, start+r]  # X 轴显示 20~50

# %%
# 执行后 会自动宽度
f.layout.autosize=False
f.layout.autosize=True

# %%
f.layout.autosize
# Out:
# True

# %%
from cracknuts.trace import ZarrTraceDataset

zd = ZarrTraceDataset.load(r'D:\work\01.testing\02.fly(gpio02)\cracknuts\tests\jupyter\dataset\20251029153409_1200_power_8m_30.zarr')

p = zd.plot()
p.show_trace(0, slice(2,20))
f = p.plot_line()
f
# 执行后 会自动宽度
f.layout.autosize=False
f.layout.autosize=True
