# %% [markdown]
# ## GPIO 控制

# %%
import cracknuts as cn

# %%
ip = '192.168.0.15' # 设备IP地址，请根据实际情况修改

s1 = cn.cracker_s1(ip)
s1.connect(force_update_bin=True, force_write_default_config=True)  # 强制更新固件并强制写入默认配置，使设备进入初始状态方便调试

# %%
s1
