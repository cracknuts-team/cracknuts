# %%
# 引入依赖
import cracknuts as cn

# 创建 cracker 
cracker = cn.new_cracker('192.168.0.29')

# %%
cracker.connect(force_update_bin=True, force_write_default_config=True)

# %%
cracker.set_logging_level('debug')

# %%
cracker.osc_trigger_source('G')

# %%
cracker.gpio_delay(5000_000_00)

# %%
cracker.gpio_control(1)

# %%
cracker.gpio_control(0)

# %%
from cracknuts import logger
logger.set_level('warn')

# %%
cracker.get_firmware_version()

# %%
cracker.register_read(base_address=0x43c10000, offset=0x24)

# %%
cracker.register_read(base_address=0x43C20000, offset=0x1c)

# %%
cracker.register_read(base_address=0x43c10000, offset=0x28)

# %%
cracker.register_write(base_address=0x43c10000, offset=0x28, data=500_000_00)

# %%
# gpio2 高电平
cracker.register_write(base_address=0x43c10000, offset=0x24, data=1)

# %%
cracker.register_write(base_address=0x43c10000, offset=0x24, data=0)

# %%
cracker.get_id() # 获取设备ID

# %%
import random
import time
from cracknuts.cracker import serial


cmd_set_aes_enc_key = "01 00 00 00 00 00 00 10"
cmd_aes_enc = "01 02 00 00 00 00 00 10"

aes_key = "11 22 33 44 55 66 77 88 99 00 aa bb cc dd ee ff"
aes_data_len = 16

sample_length = 80_000_000
# sample_length = 8_000

def init(c):
    cracker.nut_voltage_enable()
    cracker.nut_voltage(3.3)
    cracker.nut_clock_enable()
    cracker.nut_clock_freq('8M')
    # cracker.uart_io_enable()
    cracker.osc_sample_clock('48m')
    cracker.osc_sample_length(sample_length)
    # cracker.osc_trigger_source('N')
    cracker.osc_analog_gain('A', 50)
    # cracker.osc_trigger_level(0)
    cracker.osc_trigger_mode('E')
    cracker.osc_trigger_edge('U')
    cracker.osc_trigger_source('G')
    cracker.osc_analog_enable('A')
    cracker.osc_analog_disable('B')
    cracker.register_write(base_address=0x43c10000, offset=0x28, data=0)
    cracker.osc_sample_clock('8m')
    cracker.uart_config(baudrate=serial.Baudrate.BAUDRATE_115200, bytesize=serial.Bytesize.EIGHTBITS, parity=serial.Parity.PARITY_NONE, stopbits=serial.Stopbits.STOPBITS_ONE)

    time.sleep(2)
    cmd = cmd_set_aes_enc_key + aes_key
    status, ret = cracker.uart_transmit_receive(cmd, timeout=1000, rx_count=6)

def do(cracer, count):
    time.sleep(5)
    cracker.register_write(base_address=0x43c10000, offset=0x24, data=1)
    # plaintext_data = random.randbytes(aes_data_len)
    # tx_data = bytes.fromhex(cmd_aes_enc.replace(' ', '')) + plaintext_data
    # status, ret = cracker.uart_transmit_receive(tx_data, rx_count= 6 + aes_data_len, is_trigger=True)
    time.sleep(10)
    cracker.register_write(base_address=0x43c10000, offset=0x24, data=0)
    return {
        "plaintext": b'',
        "ciphertext": b'',
        "key": b''
    }


def finish(c):
    ...
    # print('optional behavior')


acq = cn.new_acquisition(cracker, init=init, do=do, finish=finish)
acq.sample_length = 20

# %%
cn.panel(acq)
# Out:
# CracknutsPanelWidget(acq_run_progress={'finished': 0, 'total': -1}, connect_status=True, custom_y_range={'0': …
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761623572.3534346
# set trace end 1761623572.9647708: 0.6113362312316895
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761623594.8413634
# set trace end 1761623595.4413755: 0.6000120639801025
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761623617.3269029
# set trace end 1761623617.88741: 0.56050705909729
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761623639.752633
# set trace end 1761623640.3455765: 0.5929434299468994
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761623662.217109
# set trace end 1761623662.8115447: 0.5944356918334961
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761623684.8496156
# set trace end 1761623685.4702792: 0.6206636428833008
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761623707.388661
# set trace end 1761623707.983735: 0.5950741767883301
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761623729.8852746
# set trace end 1761623731.022092: 1.136817455291748
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761623752.9305801
# set trace end 1761623753.533851: 0.6032707691192627
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761623775.4038863
# set trace end 1761623776.1181474: 0.7142610549926758
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761623797.9698913
# set trace end 1761623798.543321: 0.5734295845031738
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761623820.5000196
# set trace end 1761623821.1201935: 0.6201739311218262
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761623843.0228841
# set trace end 1761623843.6191618: 0.5962777137756348
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761623865.4290514
# set trace end 1761623866.0218263: 0.5927748680114746
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761623887.7338943
# set trace end 1761623888.325459: 0.5915646553039551
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761623910.2454844
# set trace end 1761623910.8352523: 0.5897679328918457
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761623932.6344156
# set trace end 1761623933.2449198: 0.610504150390625
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761623955.1482058
# set trace end 1761623955.7566428: 0.6084370613098145
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761623977.6251216
# set trace end 1761623978.2477458: 0.6226241588592529
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624000.103429
# set trace end 1761624000.6921313: 0.5887022018432617
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624022.5208075
# set trace end 1761624023.121393: 0.6005854606628418
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624044.8832977
# set trace end 1761624045.486991: 0.6036932468414307
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624067.4082222
# set trace end 1761624068.0072117: 0.5989894866943359
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624089.8628323
# set trace end 1761624090.4584756: 0.5956432819366455
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624112.2916121
# set trace end 1761624112.8920023: 0.6003901958465576
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624134.7672932
# set trace end 1761624135.3617687: 0.594475507736206
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624157.1761937
# set trace end 1761624157.7597222: 0.5835285186767578
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624179.5665557
# set trace end 1761624180.1563182: 0.5897624492645264
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624202.0235195
# set trace end 1761624202.629048: 0.6055285930633545
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624224.4072285
# set trace end 1761624224.977489: 0.5702605247497559
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624246.8824627
# set trace end 1761624247.4819899: 0.59952712059021
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624269.407683
# set trace end 1761624269.9814062: 0.573723316192627
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624291.9225507
# set trace end 1761624292.5096922: 0.5871415138244629
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624314.2290385
# set trace end 1761624314.823458: 0.5944194793701172
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624336.607931
# set trace end 1761624337.2052221: 0.5972912311553955
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624359.1028094
# set trace end 1761624359.7113178: 0.6085083484649658
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624381.6147661
# set trace end 1761624382.207966: 0.5931999683380127
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624404.1504378
# set trace end 1761624404.7516487: 0.6012108325958252
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624426.5825672
# set trace end 1761624427.1758063: 0.5932390689849854
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624448.9935503
# set trace end 1761624449.562937: 0.5693867206573486
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624471.1652882
# set trace end 1761624471.7425263: 0.5772380828857422
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624493.2943416
# set trace end 1761624493.8511949: 0.5568532943725586
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624515.519638
# set trace end 1761624516.0733492: 0.5537111759185791
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624537.7027383
# set trace end 1761624538.2947118: 0.5919735431671143
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624559.912838
# set trace end 1761624560.512727: 0.5998890399932861
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624582.0610085
# set trace end 1761624582.6310422: 0.5700337886810303
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624604.3606122
# set trace end 1761624604.928923: 0.5683107376098633
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624626.5075817
# set trace end 1761624627.0837996: 0.5762178897857666
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624648.8221107
# set trace end 1761624649.4754348: 0.6533241271972656
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624671.0979345
# set trace end 1761624671.7203703: 0.6224358081817627
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624693.2231016
# set trace end 1761624693.7853904: 0.562288761138916
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624715.3580728
# set trace end 1761624715.938198: 0.5801253318786621
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624737.514111
# set trace end 1761624738.0744543: 0.5603432655334473
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624759.6797144
# set trace end 1761624760.250588: 0.570873498916626
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624781.806917
# set trace end 1761624782.3884494: 0.5815324783325195
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624803.9653301
# set trace end 1761624804.5301313: 0.5648012161254883
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624826.0801144
# set trace end 1761624826.6442735: 0.5641591548919678
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624848.1675444
# set trace end 1761624848.8092647: 0.6417202949523926
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624870.3084137
# set trace end 1761624870.8880544: 0.5796406269073486
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624892.4536371
# set trace end 1761624893.004224: 0.5505869388580322
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624914.5525565
# set trace end 1761624915.0994852: 0.5469286441802979
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624936.8217535
# set trace end 1761624937.396148: 0.5743944644927979
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624958.964551
# set trace end 1761624959.5336444: 0.5690934658050537
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761624981.1113908
# set trace end 1761624981.6959786: 0.584587812423706
# get wave offset 0 length 32000000
# (32000000,)
# get wave offset 32000000 length 32000000
# (32000000,)
# get wave offset 64000000 length 16000000
# (16000000,)
# start set trace 1761625003.250524
# set trace end 1761625003.8696544: 0.6191303730010986
# start set trace 1761625018.8740451
# set trace end 1761625019.4953363: 0.6212911605834961

# %%
cracker.nut_voltage(3.3)

# %%
cracker.nut_voltage_enable()

# %%
cracker.nut_voltage_disable()

# %%
tp = r'D:\work\00.project\cracknuts\tests\jupyter\dataset\20251027111505.zarr'
